# %%
df["Atist Names"].value_counts().head(10).plot(
    kind="bar",
    title="Artists with Most Appearances in Spotify Global Weekly Chart"
)
# Out:
# <Axes: title={'center': 'Artists with Most Appearances in Spotify Global Weekly Chart'}, xlabel='Artist Names'>

# %% [markdown]
# ## Objective
# Analyze Spotify global weekly chart data to understand artist dominance and repeat chart presence.
#
# ## Question
# Which artists appear most frequently in the global weekly chart?
#
# ## Insight
# The global weekly chart is dominated not only by current pop leaders but also by legacy and seasonal artists, indicating that sustained listener demand and catalog longevity play a major role in repeat chart presence.
